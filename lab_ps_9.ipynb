# %% [markdown]
# Nikhil Rajendra Dhumal
#
# 21102A0009
#
# CMPN A
#
# [Github](https://github.com/nikhil-dhumal/ML_Practicals/blob/main/lab_ps_9.ipynb)

# %%
import numpy as np
import pandas as pd

# %%
with open('datasets/optdigits.tra', 'r') as f:
  lines = f.readlines()

data = []
labels = [f'f{i}' for i in range(1,65)]
labels.append('digit')
for line in lines:
  parts = line.strip().split(',')
  features = [int(x) for x in parts]
  data.append(features)

train_data = pd.DataFrame(data,columns = labels)
train_data
# Out:
#       f1  f2  f3  f4  f5  f6  f7  f8  f9  f10  ...  f56  f57  f58  f59  f60  \
# 0      0   1   6  15  12   1   0   0   0    7  ...    0    0    0    6   14
# 1      0   0  10  16   6   0   0   0   0    7  ...    0    0    0   10   16
# 2      0   0   8  15  16  13   0   0   0    1  ...    0    0    0    9   14
# 3      0   0   0   3  11  16   0   0   0    0  ...    0    0    0    0    1
# 4      0   0   5  14   4   0   0   0   0    0  ...    0    0    0    4   12
# ...   ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...  ...  ...  ...  ...
# 3818   0   0   5  13  11   2   0   0   0    2  ...    0    0    0    8   13
# 3819   0   0   0   1  12   1   0   0   0    0  ...    0    0    0    0    4
# 3820   0   0   3  15   0   0   0   0   0    0  ...    0    0    0    4   14
# 3821   0   0   6  16   2   0   0   0   0    0  ...    0    0    0    5   16
# 3822   0   0   2  15  16  13   1   0   0    0  ...    0    0    0    4   14
#
#       f61  f62  f63  f64  digit
# 0       7    1    0    0      0
# 1      15    3    0    0      0
# 2       0    0    0    0      7
# 3      15    2    0    0      4
# 4      14    7    0    0      6
# ...   ...  ...  ...  ...    ...
# 3818   15   10    1    0      9
# 3819    9    0    0    0      4
# 3820   16    9    0    0      6
# 3821   16   16    5    0      6
# 3822    1    0    0    0      7
#
# [3823 rows x 65 columns]

# %%
with open('datasets/optdigits.tes', 'r') as f:
  lines = f.readlines()

data = []
labels = [f'f{i}' for i in range(1,65)]
labels.append('digit')
for line in lines:
  parts = line.strip().split(',')
  features = [int(x) for x in parts]
  data.append(features)

test_data = pd.DataFrame(data, columns = labels)
test_data
# Out:
#       f1  f2  f3  f4  f5  f6  f7  f8  f9  f10  ...  f56  f57  f58  f59  f60  \
# 0      0   0   5  13   9   1   0   0   0    0  ...    0    0    0    6   13
# 1      0   0   0  12  13   5   0   0   0    0  ...    0    0    0    0   11
# 2      0   0   0   4  15  12   0   0   0    0  ...    0    0    0    0    3
# 3      0   0   7  15  13   1   0   0   0    8  ...    0    0    0    7   13
# 4      0   0   0   1  11   0   0   0   0    0  ...    0    0    0    0    2
# ...   ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...  ...  ...  ...  ...
# 1792   0   0   4  10  13   6   0   0   0    1  ...    0    0    0    2   14
# 1793   0   0   6  16  13  11   1   0   0    0  ...    0    0    0    6   16
# 1794   0   0   1  11  15   1   0   0   0    0  ...    0    0    0    2    9
# 1795   0   0   2  10   7   0   0   0   0    0  ...    0    0    0    5   12
# 1796   0   0  10  14   8   1   0   0   0    2  ...    0    0    1    8   12
#
#       f61  f62  f63  f64  digit
# 0      10    0    0    0      0
# 1      16   10    0    0      1
# 2      11   16    9    0      2
# 3      13    9    0    0      3
# 4      16    4    0    0      4
# ...   ...  ...  ...  ...    ...
# 1792   15    9    0    0      9
# 1793   14    6    0    0      0
# 1794   13    6    0    0      8
# 1795   16   12    0    0      9
# 1796   14   12    1    0      8
#
# [1797 rows x 65 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
std_train_data = scaler.fit_transform(train_data.drop('digit', axis = 1))
std_test_data = scaler.transform(test_data.drop('digit', axis = 1))

# %%
train_data
# Out:
#       f1  f2  f3  f4  f5  f6  f7  f8  f9  f10  ...  f56  f57  f58  f59  f60  \
# 0      0   1   6  15  12   1   0   0   0    7  ...    0    0    0    6   14
# 1      0   0  10  16   6   0   0   0   0    7  ...    0    0    0   10   16
# 2      0   0   8  15  16  13   0   0   0    1  ...    0    0    0    9   14
# 3      0   0   0   3  11  16   0   0   0    0  ...    0    0    0    0    1
# 4      0   0   5  14   4   0   0   0   0    0  ...    0    0    0    4   12
# ...   ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...  ...  ...  ...  ...
# 3818   0   0   5  13  11   2   0   0   0    2  ...    0    0    0    8   13
# 3819   0   0   0   1  12   1   0   0   0    0  ...    0    0    0    0    4
# 3820   0   0   3  15   0   0   0   0   0    0  ...    0    0    0    4   14
# 3821   0   0   6  16   2   0   0   0   0    0  ...    0    0    0    5   16
# 3822   0   0   2  15  16  13   1   0   0    0  ...    0    0    0    4   14
#
#       f61  f62  f63  f64  digit
# 0       7    1    0    0      0
# 1      15    3    0    0      0
# 2       0    0    0    0      7
# 3      15    2    0    0      4
# 4      14    7    0    0      6
# ...   ...  ...  ...  ...    ...
# 3818   15   10    1    0      9
# 3819    9    0    0    0      4
# 3820   16    9    0    0      6
# 3821   16   16    5    0      6
# 3822    1    0    0    0      7
#
# [3823 rows x 65 columns]

# %%
from sklearn.decomposition import PCA

# %%
pca1 = PCA(n_components = 2)
pca_train_data1 = pca1.fit_transform(std_train_data)
pca_test_data1 = pca1.transform(std_test_data)

# %%
pca2 = PCA(n_components = 3)
pca_train_data2 = pca2.fit_transform(std_train_data)
pca_test_data2 = pca2.transform(std_test_data)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 8))

plt.scatter(pca_train_data1[:, 0], pca_train_data1[:, 1], c=train_data['digit'], cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %%
import plotly.express as px

# %%
fig = px.scatter_3d(x = pca_train_data2[:, 0], y = pca_train_data2[:, 1], z = pca_train_data2[:, 2], color = train_data['digit'],
                    color_continuous_scale = 'viridis', width = 1000, height = 700)
fig.show()
